# %% [markdown]
# <a href="https://colab.research.google.com/github/umakasa/Privacy-Preserving-Synthetic-Data-Generation-Using-Generative-AI./blob/main/Untitled70.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -q sdv catboost xgboost
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 210.0/210.0 kB 5.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 97.1/97.1 MB 8.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 140.0/140.0 kB 10.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.6/15.6 MB 72.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.7/52.7 kB 3.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.5/75.5 kB 3.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.0/207.0 kB 13.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 69.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 90.2/90.2 kB 7.8 MB/s eta 0:00:00

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

from google.colab import files

from sdv.metadata import Metadata
from sdv.single_table import CTGANSynthesizer

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    classification_report
)

from catboost import CatBoostClassifier
from xgboost import XGBClassifier

from scipy.stats import ks_2samp

import warnings
warnings.filterwarnings("ignore")

print("All libraries imported successfully!")
# Out:
# All libraries imported successfully!

# %%
uploaded = files.upload()
# Out:
#      <input type="file" id="files-66d6f14b-01a6-484e-8341-571eefbaf2b5" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-66d6f14b-01a6-484e-8341-571eefbaf2b5">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
filename = list(uploaded.keys())[0]

df = pd.read_csv("/content/adult.csv")

print("Dataset loaded successfully!")
print("File:", filename)
print("Dataset shape:", df.shape)

display(df.head(10))
# Out:
# Dataset loaded successfully!
# File: adult.csv
# Dataset shape: (32561, 15)
#    age    workclass  fnlwgt     education  education.num marital.status  \
# 0   90            ?   77053       HS-grad              9        Widowed
# 1   82      Private  132870       HS-grad              9        Widowed
# 2   66            ?  186061  Some-college             10        Widowed
# 3   54      Private  140359       7th-8th              4       Divorced
# 4   41      Private  264663  Some-college             10      Separated
# 5   34      Private  216864       HS-grad              9       Divorced
# 6   38      Private  150601          10th              6      Separated
# 7   74    State-gov   88638     Doctorate             16  Never-married
# 8   68  Federal-gov  422013       HS-grad              9       Divorced
# 9   41      Private   70037  Some-college             10  Never-married
#
#           occupation    relationship   race     sex  capital.gain  \
# ...

# %%
df.columns = (
    df.columns
    .str.strip()
    .str.lower()
)

print("Columns:")
print(df.columns.tolist())
# Out:
# Columns:
# ['age', 'workclass', 'fnlwgt', 'education', 'education.num', 'marital.status', 'occupation', 'relationship', 'race', 'sex', 'capital.gain', 'capital.loss', 'hours.per.week', 'native.country', 'income']

# %%
# Remove spaces from string values
for col in df.select_dtypes(include="object").columns:
    df[col] = df[col].astype(str).str.strip()

# Convert ? to missing
df = df.replace("?", np.nan)

# Remove missing rows
df = df.dropna().reset_index(drop=True)

print("After cleaning:")
print("Rows:", len(df))
print("Columns:", len(df.columns))

print("\nMissing values:")
print(df.isnull().sum())
# Out:
# After cleaning:
# Rows: 30162
# Columns: 15
#
# Missing values:
# age               0
# workclass         0
# fnlwgt            0
# education         0
# education.num     0
# marital.status    0
# occupation        0
# relationship      0
# race              0
# sex               0
# capital.gain      0
# capital.loss      0
# hours.per.week    0
# native.country    0
# income            0
# dtype: int64

# %%
print("Income distribution:")

print(
    df["income"].value_counts()
)

print("\nPercentage:")
print(
    df["income"].value_counts(normalize=True) * 100
)
# Out:
# Income distribution:
# income
# <=50K    22654
# >50K      7508
# Name: count, dtype: int64
#
# Percentage:
# income
# <=50K    75.107751
# >50K     24.892249
# Name: proportion, dtype: float64

# %%
target = "income"

feature_columns = [
    col for col in df.columns
    if col != target
]

numeric_columns = df[
    feature_columns
].select_dtypes(
    include=["int64", "float64"]
).columns.tolist()

categorical_columns = df[
    feature_columns
].select_dtypes(
    include=["object", "category"]
).columns.tolist()

print("Numerical columns:")
print(numeric_columns)

print("\nCategorical columns:")
print(categorical_columns)
# Out:
# Numerical columns:
# ['age', 'fnlwgt', 'education.num', 'capital.gain', 'capital.loss', 'hours.per.week']
#
# Categorical columns:
# ['workclass', 'education', 'marital.status', 'occupation', 'relationship', 'race', 'sex', 'native.country']

# %%
private_df = df.copy()

np.random.seed(42)

# Controlled privacy noise
private_df["age"] = (
    private_df["age"] +
    np.random.laplace(
        loc=0,
        scale=0.5,
        size=len(private_df)
    )
).clip(17, 90)

private_df["hours.per.week"] = (
    private_df["hours.per.week"] +
    np.random.laplace(
        loc=0,
        scale=0.5,
        size=len(private_df)
    )
).clip(1, 99)

print("Privacy-preserving preprocessing completed!")

display(private_df.head(10))
# Out:
# Privacy-preserving preprocessing completed!
#          age         workclass  fnlwgt     education  education.num  \
# 0  81.855545           Private  132870       HS-grad              9
# 1  55.158487           Private  140359       7th-8th              4
# 2  41.311799           Private  264663  Some-college             10
# 3  34.109898           Private  216864       HS-grad              9
# 4  37.417684           Private  150601          10th              6
# 5  73.417606         State-gov   88638     Doctorate             16
# 6  66.923638       Federal-gov  422013       HS-grad              9
# 7  45.659042           Private  172274     Doctorate             16
# 8  38.112967  Self-emp-not-inc  164526   Prof-school             15
# 9  52.269051           Private  129177     Bachelors             13
#
#   marital.status         occupation    relationship   race     sex  \
# 0        Widowed    Exec-managerial   Not-in-family  White  Female
# ...

# %%
metadata = Metadata.detect_from_dataframe(
    data=private_df,
    table_name="adult_privacy_data"
)

metadata.validate()

print("Metadata created successfully!")
# Out:
# Metadata created successfully!

# %%
synthesizer = CTGANSynthesizer(
    metadata,
    epochs=300,
    verbose=True
)

print("Starting CTGAN training...")

synthesizer.fit(private_df)

print("CTGAN training completed!")
# Out:
# Starting CTGAN training...
# Gen. (-00.56) | Discrim. (-00.13): 100%|██████████| 300/300 [59:44<00:00, 11.95s/it]
# CTGAN training completed!

# %%
synthetic_df = synthesizer.sample(
    num_rows=len(private_df)
)

print("Synthetic data generated!")
print("Synthetic shape:", synthetic_df.shape)

display(synthetic_df.head(10))
# Out:
# Synthetic data generated!
# Synthetic shape: (30162, 15)
#          age         workclass  fnlwgt     education  education.num  \
# 0  30.355753           Private  117270     Bachelors             13
# 1  41.569512         Local-gov  275663       5th-6th              4
# 2  21.474743           Private  209335  Some-college              4
# 3  40.058658       Federal-gov   65073     Bachelors             13
# 4  48.160555           Private  110239          12th             12
# 5  38.518391           Private  279994           9th              5
# 6  35.905751           Private   84678     Bachelors             13
# 7  22.944326         State-gov  174297  Some-college              9
# 8  37.284871           Private   78245     Bachelors             14
# 9  40.025635  Self-emp-not-inc  118881   Prof-school             15
#
#        marital.status       occupation    relationship                race  \
# 0       Never-married   Prof-specialty   Not-in-family               White
# ...

# %%
print("Original dataset:")
print(df.shape)

print("\nSynthetic dataset:")
print(synthetic_df.shape)

print("\nSynthetic missing values:")
print(synthetic_df.isnull().sum())
# Out:
# Original dataset:
# (30162, 15)
#
# Synthetic dataset:
# (30162, 15)
#
# Synthetic missing values:
# age               0
# workclass         0
# fnlwgt            0
# education         0
# education.num     0
# marital.status    0
# occupation        0
# relationship      0
# race              0
# sex               0
# capital.gain      0
# capital.loss      0
# hours.per.week    0
# native.country    0
# income            0
# dtype: int64

# %%
synthetic_df.to_csv(
    "privacy_preserving_synthetic_adult.csv",
    index=False
)

print("Synthetic dataset saved successfully!")
# Out:
# Synthetic dataset saved successfully!

# %%
X_train = synthetic_df.drop(
    columns=[target]
).copy()

y_train = synthetic_df[target].astype(str)

X_test = df.drop(
    columns=[target]
).copy()

y_test = df[target].astype(str)

# Make categorical columns strings
for col in categorical_columns:

    X_train[col] = X_train[col].astype(str)
    X_test[col] = X_test[col].astype(str)

print("Training data:", X_train.shape)
print("Testing data:", X_test.shape)
# Out:
# Training data: (30162, 14)
# Testing data: (30162, 14)

# %%
cat_model = CatBoostClassifier(
    iterations=800,
    depth=8,
    learning_rate=0.04,
    loss_function="Logloss",
    eval_metric="Accuracy",
    random_seed=42,
    verbose=100,
    l2_leaf_reg=5,
    random_strength=1,
    border_count=128,
    thread_count=-1
)

print("Training CatBoost...")

cat_model.fit(
    X_train,
    y_train,
    cat_features=categorical_columns
)

print("CatBoost training completed!")
# Out:
# Training CatBoost...
# 0:	learn: 0.8278629	total: 186ms	remaining: 2m 28s
# 100:	learn: 0.8533585	total: 11.5s	remaining: 1m 19s
# 200:	learn: 0.8608182	total: 21.6s	remaining: 1m 4s
# 300:	learn: 0.8659240	total: 31.4s	remaining: 52.1s
# 400:	learn: 0.8709303	total: 42.7s	remaining: 42.5s
# 500:	learn: 0.8752735	total: 54.1s	remaining: 32.3s
# 600:	learn: 0.8809098	total: 1m 5s	remaining: 21.8s
# 700:	learn: 0.8859492	total: 1m 16s	remaining: 10.8s
# 799:	learn: 0.8912207	total: 1m 27s	remaining: 0us
# CatBoost training completed!

# %%
cat_predictions = cat_model.predict(X_test)

cat_predictions = np.array(
    cat_predictions
).reshape(-1).astype(str)

cat_accuracy = accuracy_score(
    y_test,
    cat_predictions
)

cat_precision = precision_score(
    y_test,
    cat_predictions,
    average="weighted"
)

cat_recall = recall_score(
    y_test,
    cat_predictions,
    average="weighted"
)

cat_f1 = f1_score(
    y_test,
    cat_predictions,
    average="weighted"
)

print("\n======================================")
print("       CATBOOST RESULTS")
print("======================================")

print(f"Accuracy  : {cat_accuracy * 100:.2f}%")
print(f"Precision : {cat_precision * 100:.2f}%")
print(f"Recall    : {cat_recall * 100:.2f}%")
print(f"F1-Score  : {cat_f1 * 100:.2f}%")
# Out:
# ...
#        CATBOOST RESULTS
# ...
# Accuracy  : 83.62%
# Precision : 83.12%
# Recall    : 83.62%
# F1-Score  : 83.30%

# %%
# Convert categorical data to one-hot encoding

combined = pd.concat(
    [
        synthetic_df.drop(columns=[target]),
        df.drop(columns=[target])
    ],
    axis=0,
    ignore_index=True
)

combined_encoded = pd.get_dummies(
    combined,
    columns=categorical_columns,
    drop_first=False
)

X_train_xgb = combined_encoded.iloc[
    :len(synthetic_df)
].copy()

X_test_xgb = combined_encoded.iloc[
    len(synthetic_df):
].copy()

# Encode target
label_encoder = LabelEncoder()

all_y = pd.concat(
    [
        synthetic_df[target].astype(str),
        df[target].astype(str)
    ]
)

label_encoder.fit(all_y)

y_train_xgb = label_encoder.transform(
    synthetic_df[target].astype(str)
)

y_test_xgb = label_encoder.transform(
    df[target].astype(str)
)

print("XGBoost data prepared!")
print("Training shape:", X_train_xgb.shape)
print("Testing shape:", X_test_xgb.shape)
# Out:
# XGBoost data prepared!
# Training shape: (30162, 104)
# Testing shape: (30162, 104)

# %%
xgb_model = XGBClassifier(
    n_estimators=700,
    max_depth=6,
    learning_rate=0.04,
    min_child_weight=2,
    subsample=0.9,
    colsample_bytree=0.9,
    gamma=0,
    reg_alpha=0.05,
    reg_lambda=1.0,
    objective="binary:logistic",
    eval_metric="logloss",
    random_state=42,
    n_jobs=-1
)

print("Training XGBoost...")

xgb_model.fit(
    X_train_xgb,
    y_train_xgb
)

print("XGBoost training completed!")
# Out:
# Training XGBoost...
# XGBoost training completed!

# %%
xgb_predictions = xgb_model.predict(
    X_test_xgb
)

xgb_accuracy = accuracy_score(
    y_test_xgb,
    xgb_predictions
)

xgb_precision = precision_score(
    y_test_xgb,
    xgb_predictions,
    average="weighted"
)

xgb_recall = recall_score(
    y_test_xgb,
    xgb_predictions,
    average="weighted"
)

xgb_f1 = f1_score(
    y_test_xgb,
    xgb_predictions,
    average="weighted"
)

print("\n======================================")
print("       XGBOOST RESULTS")
print("======================================")

print(f"Accuracy  : {xgb_accuracy * 100:.2f}%")
print(f"Precision : {xgb_precision * 100:.2f}%")
print(f"Recall    : {xgb_recall * 100:.2f}%")
print(f"F1-Score  : {xgb_f1 * 100:.2f}%")
# Out:
# ...
#        XGBOOST RESULTS
# ...
# Accuracy  : 83.73%
# Precision : 83.23%
# Recall    : 83.73%
# F1-Score  : 83.41%

# %%
comparison = pd.DataFrame({
    "Model": [
        "Previous Random Forest",
        "CatBoost",
        "XGBoost",
        "Multinomial Naive Bayes"
    ],

    "Accuracy": [
        79.57,
        cat_accuracy * 100,
        xgb_accuracy * 100,
        77.92
    ]
})

display(comparison)
# Out:
#                      Model   Accuracy
# 0   Previous Random Forest  79.570000
# 1                 CatBoost  83.621776
# 2                  XGBoost  83.727870
# 3  Multinomial Naive Bayes  77.920000

# %%
best_accuracy = max(
    cat_accuracy,
    xgb_accuracy
)

if cat_accuracy >= xgb_accuracy:
    best_model_name = "CatBoost"
else:
    best_model_name = "XGBoost"

print("======================================")
print("        BEST MODEL RESULT")
print("======================================")

print("Best Model:", best_model_name)
print(f"Best Accuracy: {best_accuracy * 100:.2f}%")

if best_accuracy * 100 >= 81.6:
    print("\nTARGET ACHIEVED!")
    print("Accuracy is above 81.6%.")
else:
    print("\nTarget not reached yet.")
    print("We need another optimization experiment.")
# Out:
# ...
#         BEST MODEL RESULT
# ...
# Best Model: XGBoost
# Best Accuracy: 83.73%
#
# TARGET ACHIEVED!
# Accuracy is above 81.6%.

# %%
numerical_columns = [
    col for col in numeric_columns
    if col in synthetic_df.columns
]

fidelity_results = []

for col in numerical_columns:

    real_values = pd.to_numeric(
        df[col],
        errors="coerce"
    ).dropna()

    synthetic_values = pd.to_numeric(
        synthetic_df[col],
        errors="coerce"
    ).dropna()

    ks_stat, p_value = ks_2samp(
        real_values,
        synthetic_values
    )

    fidelity_results.append({
        "Feature": col,
        "KS Statistic": ks_stat,
        "P-Value": p_value
    })

fidelity_df = pd.DataFrame(
    fidelity_results
)

display(fidelity_df)
# Out:
#           Feature  KS Statistic        P-Value
# 0             age      0.059247   1.854152e-46
# 1          fnlwgt      0.088224  1.391815e-102
# 2   education.num      0.051024   1.456452e-34
# 3    capital.gain      0.328128   0.000000e+00
# 4    capital.loss      0.090544  4.885436e-108
# 5  hours.per.week      0.366421   0.000000e+00

# %%
real_records = set(
    df.astype(str).apply(
        lambda row: "|".join(row),
        axis=1
    )
)

synthetic_records = set(
    synthetic_df.astype(str).apply(
        lambda row: "|".join(row),
        axis=1
    )
)

matching_records = (
    real_records.intersection(
        synthetic_records
    )
)

duplication_rate = (
    len(matching_records) /
    len(synthetic_records)
) * 100

print("======================================")
print("       PRIVACY EVALUATION")
print("======================================")

print(
    "Exact matching records:",
    len(matching_records)
)

print(
    f"Exact duplication rate: {duplication_rate:.4f}%"
)
# Out:
# ...
#        PRIVACY EVALUATION
# ...
# Exact matching records: 0
# Exact duplication rate: 0.0000%

# %%
final_results = pd.DataFrame({
    "Evaluation": [
        "Data Fidelity",
        "ML Accuracy",
        "ML Precision",
        "ML Recall",
        "ML F1-Score",
        "Privacy - Exact Duplication"
    ],

    "Metric": [
        "Average KS Statistic",
        "Best Model Accuracy",
        "Best Model Precision",
        "Best Model Recall",
        "Best Model F1-Score",
        "Exact Match Rate"
    ],

    "Result": [
        f"{fidelity_df['KS Statistic'].mean():.4f}",
        f"{best_accuracy * 100:.2f}%",
        (
            f"{cat_precision * 100:.2f}%"
            if cat_accuracy >= xgb_accuracy
            else f"{xgb_precision * 100:.2f}%"
        ),
        (
            f"{cat_recall * 100:.2f}%"
            if cat_accuracy >= xgb_accuracy
            else f"{xgb_recall * 100:.2f}%"
        ),
        (
            f"{cat_f1 * 100:.2f}%"
            if cat_accuracy >= xgb_accuracy
            else f"{xgb_f1 * 100:.2f}%"
        ),
        f"{duplication_rate:.4f}%"
    ]
})

display(final_results)
# Out:
#                     Evaluation                Metric   Result
# 0                Data Fidelity  Average KS Statistic   0.1639
# 1                  ML Accuracy   Best Model Accuracy   83.73%
# 2                 ML Precision  Best Model Precision   83.23%
# 3                    ML Recall     Best Model Recall   83.73%
# 4                  ML F1-Score   Best Model F1-Score   83.41%
# 5  Privacy - Exact Duplication      Exact Match Rate  0.0000%
